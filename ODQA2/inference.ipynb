# %% [markdown]
# ### Retrieval - Sparse Embedding(BM25)

# %%
import json
import os, sys
import datasets
from box import Box

sys.path.append(os.path.dirname(os.path.abspath(os.getcwd())))
from retrieval.sparse.src.sparse_retrieval import SparseRetrieval

# %%
config = {"retriever": "../retrieval/sparse/config/sparse_retrieval_config_example.json",
          "reader": "../reader2/config/extraction_config.json"}

config = Box(config)

with open(config.retriever, 'r', encoding='utf-8') as f:
    retriever_config = json.load(f)
    retriever_config = Box(retriever_config)

with open(config.reader, 'r', encoding='utf-8') as f:
    reader_config = json.load(f)
    reader_config = Box(reader_config)

retriever_config, reader_config
# Out:
# (Box({'corpus_data_path': '/data/ephemeral/home/osh/data/v0.0.2/wikipedia_documents.json', 'embedding_method': 'bm25', 'topk': 10, 'tokenizer_model_name': 'klue/bert-base', 'eval_data_path': '/data/ephemeral/home/osh/data/v0.0.2', 'eval_metric': ['hit', 'mrr'], 'retrieval_save_path': '/data/ephemeral/home/osh/level2-mrc-nlp-06/ODQA2/outputs/retrieval/v2-test.csv'}),
#  Box({'model_args': {'model_name_or_path': 'uomnf97/klue-roberta-finetuned-korquad-v2', 'config_name': None, 'tokenizer_name': None, 'generation': False, 'retrieval_type': 'dense'}, 'data_args': {'data_path': '/data/ephemeral/home/osh/data/v0.0.4', 'overwrite_cache': True, 'preprocessing_num_workers': None, 'max_seq_length': 384, 'pad_to_max_length': False, 'doc_stride': 128, 'max_answer_length': 90, 'eval_retrieval': True, 'num_clusters': 64, 'top_k_retrieval': 10, 'use_faiss': False}, 'training_args': {'output_dir': '/data/ephemeral/home/osh/level2-mrc-nlp-06/reader2/models/epoch-1', 'evaluation_strategy': 'no', 'eval_steps': 50, 'per_device_train_batch_size': 16, 'per_device_eval_batch_size': 16, 'learning_rate': 1e-05, 'num_train_epochs': 1, 'warmup_steps': 500, 'logging_dir': '../logs', 'logging_steps': 500, 'save_steps': 500, 'save_total_limit': 2, 'fp16': True, 'load_best_model_at_end': False, 'seed': 42, 'overwrite_output_dir': True, 'run_name': 'extractive-epoch-1'}}))

# %%
import pandas as pd
from transformers import AutoTokenizer

# logger.info("Loading data.")
print("Loading Corpus for Sparse Retrieval")

with open(retriever_config.corpus_data_path, "r", encoding="utf-8") as f:
    wiki = json.load(f)
wiki_df = pd.DataFrame(wiki.values())
wiki_unique_df = wiki_df.drop_duplicates(subset=["text"], keep="first")
contexts = wiki_unique_df["text"].tolist()  # unique text 추출
document_ids = wiki_unique_df["document_id"].tolist()

tokenizer = AutoTokenizer.from_pretrained(retriever_config.tokenizer_model_name, use_fast=True)
retriever = SparseRetrieval(embedding_method=retriever_config.embedding_method,
                            tokenizer=tokenizer,
                            contexts=contexts,
                            document_ids=document_ids)

if retriever_config.embedding_method == "tfidf":
    retriever.get_sparse_embedding_tfidf()
elif retriever_config.embedding_method == "bm25":
    retriever.get_sparse_embedding_bm25()

from datasets import load_from_disk, concatenate_datasets
test_dataset = load_from_disk(retriever_config.eval_data_path)['test']
# org_dataset = load_from_disk(retriever_config.eval_data_path)
# eval_df = concatenate_datasets(
#     [
#         org_dataset["train"].flatten_indices(),
#         org_dataset["validation"].flatten_indices(),
#     ]
# )
# logger.info("Evaluation dataset loaded with %d examples.", len(eval_df))
print("Evaluation dataset loaded with %d examples.", len(test_dataset))

result_df = retriever.retrieve(test_dataset, topk=retriever_config.topk, save=True, retrieval_save_path=retriever_config.retrieval_save_path)
# Out:
# Loading Corpus for Sparse Retrieval
# 10/21/2024 12:48:53 - INFO - retrieval.sparse.src.sparse_retrieval -    Loading BM25 pickle file.
# Evaluation dataset loaded with %d examples. 600
# 10/21/2024 12:48:56 - INFO - retrieval.sparse.src.sparse_retrieval -    Retrieving for dataset queries.
# Calculating BM25 scores:   0%|          | 0/600 [00:00<?, ?it/s]
# [query exhaustive search] done in 84.293 s
# Sparse retrieval:   0%|          | 0/600 [00:00<?, ?it/s]
# 10/21/2024 12:50:20 - INFO - retrieval.sparse.src.sparse_retrieval -    Completed retrieval for dataset queries.

# %% [markdown]
# ### MRC - Extraction Base

# %%
result_df.tail(1)
# Out:
#                       question            id  \
# 599  구립운석을 이루는 물질 중 널리 알려진 것은?  mrc-0-002605
#
#                                            document_id
# 599  [15241, 32440, 52986, 54675, 19751, 42355, 371...

# %%
with open('/data/ephemeral/home/osh/data/v0.0.4/wikipedia_documents.json', 'r', encoding='utf-8') as f:
    wiki = json.load(f)

# %%
result_df['context'] = None
for idx, doc_ids in enumerate(result_df['document_id']):
    result_df.loc[idx, 'context'] = ' '.join([wiki[str(i)]['text'] for i in doc_ids])

# result_df.to_csv('./outputs/retrieval/for_reader.csv')
result_df.head()
# Out:
#                                   question            id  \
# 0                    유령'은 어느 행성에서 지구로 왔는가?  mrc-1-000653
# 1          용병회사의 경기가 좋아진 것은 무엇이 끝난 이후부터인가?  mrc-1-001113
# 2  돌푸스에게 불특정 기간동안 하원이 잠시 쉬는 것을 건의 받았던 인물은?  mrc-0-002191
# 3     마오리언어와 영어, 뉴질랜드 수화를 공식 언어로 사용하는 나라는?  mrc-0-003951
# 4               디엔비엔푸 전투에서 보응우옌잡이 상대한 국가는?  mrc-1-001272
#
#                                          document_id  \
# 0  [43280, 42242, 47081, 9781, 52764, 26978, 1597...
# 1  [13590, 46223, 20081, 45867, 42721, 31128, 269...
# 2  [20554, 42418, 27161, 48970, 20553, 52884, 365...
# 3  [25557, 58770, 58774, 4180, 48055, 4248, 48049...
# 4  [18335, 22830, 17274, 40517, 22897, 27405, 485...
#
#                                              context
# 0  목성의 대기에서 보이는 줄무늬는 적도와 평행하면서 행성을 둘러싸는 대와 띠라고 불리...
# 1  냉전 종식 이후 전 세계적으로 소규모의 끊임없는 국지 분쟁들이 생겨나고 강대국들의 ...
# 2  1933년 3월, 투표 과정의 위법성에 대한 문제제기가 불거졌다. 당시 오스트리아 ...
# 3  유럽인들의 아메리카와 오세아니아 식민지화로 인해 아메리카와 오세아니아의 문화적, 민...
# 4  1926년 학생 시절 베트남청년혁명당에 가입했고 1930년에 학생 파업을 지지했다는...

# %%
import pandas as pd

result_df = pd.read_csv('./outputs/retrieval/for_reader.csv').drop(columns=['Unnamed: 0', 'document_id'])
result_df.head()
# Out:
#                                   question            id  \
# 0                    유령'은 어느 행성에서 지구로 왔는가?  mrc-1-000653
# 1          용병회사의 경기가 좋아진 것은 무엇이 끝난 이후부터인가?  mrc-1-001113
# 2  돌푸스에게 불특정 기간동안 하원이 잠시 쉬는 것을 건의 받았던 인물은?  mrc-0-002191
# 3     마오리언어와 영어, 뉴질랜드 수화를 공식 언어로 사용하는 나라는?  mrc-0-003951
# 4               디엔비엔푸 전투에서 보응우옌잡이 상대한 국가는?  mrc-1-001272
#
#                                              context
# 0  목성의 대기에서 보이는 줄무늬는 적도와 평행하면서 행성을 둘러싸는 대와 띠라고 불리...
# 1  냉전 종식 이후 전 세계적으로 소규모의 끊임없는 국지 분쟁들이 생겨나고 강대국들의 ...
# 2  1933년 3월, 투표 과정의 위법성에 대한 문제제기가 불거졌다. 당시 오스트리아 ...
# 3  유럽인들의 아메리카와 오세아니아 식민지화로 인해 아메리카와 오세아니아의 문화적, 민...
# 4  1926년 학생 시절 베트남청년혁명당에 가입했고 1930년에 학생 파업을 지지했다는...

# %%
from extractionQA import ExtractiveQA

reader = ExtractiveQA(config.reader)
# Out:
# /opt/conda/lib/python3.10/site-packages/transformers/training_args.py:1545: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(

# %%
from datasets import load_from_disk, Dataset

retrieved_test = Dataset.from_pandas(result_df)
retrieved_test
# Out:
# Dataset({
#     features: ['question', 'id', 'context'],
#     num_rows: 600
# })

# %%
reader.predict(retrieved_test, './outputs/reader')
# Out:
# Map:   0%|          | 0/600 [00:00<?, ? examples/s]
# /data/ephemeral/home/osh/level2-mrc-nlp-06/ODQA2/extractionQA.py:157: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   metric = load_metric("squad")
# 10/21/2024 14:19:43 - WARNING - accelerate.utils.other -    Detected kernel version 5.4.0, which is below the recommended minimum of 5.5.0; this can cause the process to hang. It is recommended to upgrade the kernel to the minimum version or higher.
# 10/21/2024 14:19:45 - INFO - extractionQA -    *** Evaluate ***
# /opt/conda/lib/python3.10/site-packages/transformers/trainer_pt_utils.py:483: FutureWarning: DistributedTensorGatherer is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
#     <div>
#
#       <progress value='874' max='874' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [874/874 01:43]
#     </div>
# 10/21/2024 14:21:45 - INFO - reader2.utils.utils_extraction -    Post-processing 600 example predictions split into 13975 features.
#   0%|          | 0/600 [00:00<?, ?it/s]
# 10/21/2024 14:22:31 - INFO - reader2.utils.utils_extraction -    Saving predictions to ./outputs/reader/predictions.json.
# 10/21/2024 14:22:31 - INFO - reader2.utils.utils_extraction -    Saving nbest_preds to ./outputs/reader/nbest_predictions.json.
# No metric can be presented because there is no correct answer given. Job done!
# [{'id': 'mrc-1-000653', 'prediction_text': '사만'},
#  {'id': 'mrc-1-001113', 'prediction_text': '냉전'},
#  {'id': 'mrc-0-002191', 'prediction_text': '빌헬름 미클라스'},
#  {'id': 'mrc-0-003951', 'prediction_text': '뉴질랜드'},
#  {'id': 'mrc-1-001272', 'prediction_text': '프랑스'},
#  {'id': 'mrc-1-000993', 'prediction_text': '아래턱'},
#  {'id': 'mrc-0-005021', 'prediction_text': '대의제도'},
#  {'id': 'mrc-1-000163', 'prediction_text': '광독 가스 및 그에 따른 산성비'},
#  {'id': 'mrc-0-001283', 'prediction_text': '순조 11년(1811)'},
#  {'id': 'mrc-0-004543', 'prediction_text': '고전도성 철'},
#  {'id': 'mrc-0-000439', 'prediction_text': '점쟁이'},
#  {'id': 'mrc-0-002895', 'prediction_text': '칼라치 전방 약250km 지점'},
#  {'id': 'mrc-0-000535', 'prediction_text': '롭 포드'},
#  {'id': 'mrc-1-001724', 'prediction_text': '노스햄프턴 교회'},
#  {'id': 'mrc-0-000901', 'prediction_text': '아라라기 코요미'},
#  {'id': 'mrc-0-001606', 'prediction_text': '석조 궁륭'},
#  {'id': 'mrc-0-000266', 'prediction_text': '데르브포르갈'},
#  {'id': 'mrc-0-001326', 'prediction_text': '‘자유’지에'},
#  {'id': 'mrc-0-000032', 'prediction_text': '국방부 보고서'},
#  {'id': 'mrc-0-005215', 'prediction_text': '입석대'},
#  {'id': 'mrc-0-005407', 'prediction_text': '숙의 정씨'},
#  {'id': 'mrc-0-003683', 'prediction_text': '국가인권위원회'},
#  {'id': 'mrc-0-003644', 'prediction_text': '이탈리아'},
#  {'id': 'mrc-0-002835', 'prediction_text': '망자'},
#  {'id': 'mrc-0-000049', 'prediction_text': '스토리텔링 미디어'},
#  {'id': 'mrc-1-001829', 'prediction_text': '진경동'},
#  {'id': 'mrc-1-001662', 'prediction_text': '보신 전쟁'},
#  {'id': 'mrc-0-001206', 'prediction_text': '2013년'},
#  {'id': 'mrc-0-004007', 'prediction_text': '노팅엄 대학교'},
#  {'id': 'mrc-1-000418', 'prediction_text': '일등바위'},
#  {'id': 'mrc-0-003133', 'prediction_text': '폐렴'},
#  {'id': 'mrc-0-004646', 'prediction_text': '건늠선'},
#  {'id': 'mrc-0-001058', 'prediction_text': '도리천'},
#  {'id': 'mrc-0-002361', 'prediction_text': '독립'},
#  {'id': 'mrc-0-004830', 'prediction_text': '13개'},
#  {'id': 'mrc-0-002762', 'prediction_text': '경복사'},
#  {'id': 'mrc-0-000395', 'prediction_text': '후쿠도메 시게루 중장'},
#  {'id': 'mrc-0-001668', 'prediction_text': '그의 어머니'},
#  {'id': 'mrc-0-004487', 'prediction_text': '요세푸스'},
#  {'id': 'mrc-0-001086', 'prediction_text': '초계면'},
#  {'id': 'mrc-0-004413', 'prediction_text': '호어벨리샤'},
#  {'id': 'mrc-1-000221', 'prediction_text': '잡곡 보리밥'},
#  {'id': 'mrc-0-002177', 'prediction_text': '시트로엥'},
#  {'id': 'mrc-0-003223', 'prediction_text': '폴 베나세라프'},
#  {'id': 'mrc-0-000624', 'prediction_text': '버줌'},
#  {'id': 'mrc-0-004318', 'prediction_text': '1943년 7월 2일'},
#  {'id': 'mrc-0-002764', 'prediction_text': '카에데 소이치로'},
#  {'id': 'mrc-0-001725', 'prediction_text': '스털링 실리펀트'},
#  {'id': 'mrc-0-004445', 'prediction_text': '2018년'},
#  {'id': 'mrc-0-000001', 'prediction_text': "'강연옥'"},
#  {'id': 'mrc-0-005411', 'prediction_text': '사비나'},
#  {'id': 'mrc-1-001280', 'prediction_text': '미국 대통령 우드로 윌슨'},
#  {'id': 'mrc-0-003385', 'prediction_text': '1584년(선조 17년)'},
#  {'id': 'mrc-1-001555', 'prediction_text': '소토쿠 고등학교'},
#  {'id': 'mrc-0-000854', 'prediction_text': '2008년'},
#  {'id': 'mrc-0-000504', 'prediction_text': '17세기 전반기'},
#  {'id': 'mrc-0-000988', 'prediction_text': '노포탑'},
#  {'id': 'mrc-0-003763', 'prediction_text': '『불상조성도금사적기』'},
#  {'id': 'mrc-1-001619', 'prediction_text': '토야마 미에코'},
#  {'id': 'mrc-0-004880', 'prediction_text': '남미 자브로'},
#  {'id': 'mrc-0-003177', 'prediction_text': '"연금"'},
#  {'id': 'mrc-1-001523', 'prediction_text': '니 기븐'},
#  {'id': 'mrc-1-001353', 'prediction_text': '애굽'},
#  {'id': 'mrc-0-005278', 'prediction_text': '근세'},
#  {'id': 'mrc-0-003896', 'prediction_text': '알론소 데 곤고라 마르모레조'},
#  {'id': 'mrc-0-000339', 'prediction_text': '시칠리아'},
#  {'id': 'mrc-0-001183', 'prediction_text': '러더퍼드 B. 헤이스'},
#  {'id': 'mrc-1-001155', 'prediction_text': '광고'},
#  {'id': 'mrc-0-000991', 'prediction_text': '윌리엄 3세'},
#  {'id': 'mrc-0-005328', 'prediction_text': '신라 때'},
#  {'id': 'mrc-0-002070', 'prediction_text': '압력'},
#  {'id': 'mrc-0-003298', 'prediction_text': '오카다 다케시'},
#  {'id': 'mrc-0-002453', 'prediction_text': '다이요'},
#  {'id': 'mrc-0-003274', 'prediction_text': '필라델피아'},
#  {'id': 'mrc-0-004430', 'prediction_text': '교육 평론가'},
#  {'id': 'mrc-0-003455', 'prediction_text': '스포츠 신문'},
#  {'id': 'mrc-0-003628', 'prediction_text': '공유 필명'},
#  {'id': 'mrc-0-000432', 'prediction_text': '조선건국동맹'},
#  {'id': 'mrc-0-000540', 'prediction_text': '라이네크'},
#  {'id': 'mrc-0-000607', 'prediction_text': '비정상적으로 큰 송곳니'},
#  {'id': 'mrc-0-003540', 'prediction_text': '해상 교통, 보급 확보에 충당해야 할 함정과 인력의 부족'},
#  {'id': 'mrc-1-001466', 'prediction_text': '1938년'},
#  {'id': 'mrc-0-004954', 'prediction_text': '제5중대장 김상흥 대위'},
#  {'id': 'mrc-0-004159',
#   'prediction_text': '해 (지지)단계에는 베가가 등장한다. 이긴 캐릭터가 얼굴 등을 다친 캐릭터에게 말을 한다. 상대 캐릭터가 얼굴 등을 다친 장면이 나오면 다음 단계로 넘어가고 (단, 해 (지지)단계'},
#  {'id': 'mrc-0-001235', 'prediction_text': '미치류의 화석'},
#  {'id': 'mrc-1-000813', 'prediction_text': '9월 16일 오후'},
#  {'id': 'mrc-0-002445', 'prediction_text': '콘라트 2세'},
#  {'id': 'mrc-0-004336', 'prediction_text': '예루살렘 성전'},
#  {'id': 'mrc-0-001346', 'prediction_text': '호해'},
#  {'id': 'mrc-0-003364', 'prediction_text': '아우구스투스 시대'},
#  {'id': 'mrc-0-001891', 'prediction_text': '학업에 집중하기 위해'},
#  {'id': 'mrc-0-000033', 'prediction_text': '하난야'},
#  {'id': 'mrc-0-000201', 'prediction_text': '블라인드 테스트'},
#  {'id': 'mrc-0-003670', 'prediction_text': '‘마루게’'},
#  {'id': 'mrc-0-002224', 'prediction_text': '군대 내 성소수자 권리 정책'},
#  {'id': 'mrc-0-000140', 'prediction_text': '오코 카무'},
#  {'id': 'mrc-0-001124', 'prediction_text': '노화욱'},
#  {'id': 'mrc-0-003870', 'prediction_text': '준자치구'},
#  {'id': 'mrc-0-000386', 'prediction_text': '카바드 2세'},
#  {'id': 'mrc-0-005260', 'prediction_text': '안드레아스'},
#  {'id': 'mrc-0-004345', 'prediction_text': '1991년'},
#  {'id': 'mrc-1-000376', 'prediction_text': '시나위 대금'},
#  {'id': 'mrc-0-001470', 'prediction_text': '볼가 지방'},
#  {'id': 'mrc-1-000715', 'prediction_text': '네스토리우스'},
#  {'id': 'mrc-0-002747', 'prediction_text': '믈라카 술탄국'},
#  {'id': 'mrc-1-001341', 'prediction_text': '가상 연좌시위”'},
#  {'id': 'mrc-0-003597', 'prediction_text': '기원전 11년'},
#  {'id': 'mrc-0-003509', 'prediction_text': '미국 긴축정책'},
#  {'id': 'mrc-0-001335', 'prediction_text': '노예를 해방하는 명령'},
#  {'id': 'mrc-0-004402', 'prediction_text': '1995년'},
#  {'id': 'mrc-1-001239', 'prediction_text': '쉴드 빔'},
#  {'id': 'mrc-1-000225', 'prediction_text': '1802년'},
#  {'id': 'mrc-0-003315', 'prediction_text': '보안'},
#  {'id': 'mrc-0-004971', 'prediction_text': '천도교 대종사장'},
#  {'id': 'mrc-0-004538', 'prediction_text': '밀'},
#  {'id': 'mrc-0-001940', 'prediction_text': '경문왕'},
#  {'id': 'mrc-1-000573', 'prediction_text': '큰곰자리 운동성군'},
#  {'id': 'mrc-0-005403', 'prediction_text': '1720년'},
#  {'id': 'mrc-0-002046', 'prediction_text': '모겐소'},
#  {'id': 'mrc-0-001943', 'prediction_text': '디지털 영상'},
#  {'id': 'mrc-1-001141', 'prediction_text': '《후한서》'},
#  {'id': 'mrc-0-002709', 'prediction_text': '남자의 시체'},
#  {'id': 'mrc-0-000313', 'prediction_text': '케빈 G. 린치'},
#  {'id': 'mrc-0-003110', 'prediction_text': '난씨'},
#  {'id': 'mrc-0-003155', 'prediction_text': '스카만드로스 강'},
#  {'id': 'mrc-1-001242', 'prediction_text': '볼바라'},
#  {'id': 'mrc-0-004432', 'prediction_text': '동탁과 원소'},
#  {'id': 'mrc-0-000755',
#   'prediction_text': "'구슬이'라는 애칭을 부여하기로 결정했다.\\n\\n새천년준비위원회가 공식 인정한 즈믄둥이는 2000년 1월 1일 밤 12시 0분 1초에 경기도 안양시 한림대학교 성심병원에서 태어난 남자 아이인 이태웅"},
#  {'id': 'mrc-1-001802', 'prediction_text': '호메이니'},
#  {'id': 'mrc-0-001241', 'prediction_text': '환율 부문'},
#  {'id': 'mrc-1-001457', 'prediction_text': '도요토미 히데요시'},
#  {'id': 'mrc-0-000016', 'prediction_text': '스윙'},
#  {'id': 'mrc-1-000695', 'prediction_text': '고려 말'},
#  {'id': 'mrc-1-000908', 'prediction_text': '구충제'},
#  {'id': 'mrc-0-001034', 'prediction_text': '흉기를 사용하며 협박한 부분'},
#  {'id': 'mrc-1-001735', 'prediction_text': '마리아 팔코네티'},
#  {'id': 'mrc-1-001179', 'prediction_text': '쿠페'},
#  {'id': 'mrc-1-000521', 'prediction_text': '종 맨 위'},
#  {'id': 'mrc-1-000623', 'prediction_text': '1866년'},
#  {'id': 'mrc-0-003953', 'prediction_text': '평균비용'},
#  {'id': 'mrc-0-002008', 'prediction_text': 'HA1 도메인의 18번 코돈'},
#  {'id': 'mrc-0-001699', 'prediction_text': 'SI'},
#  {'id': 'mrc-0-002374', 'prediction_text': '무로마치 막부'},
#  {'id': 'mrc-1-000086', 'prediction_text': '이승만'},
#  {'id': 'mrc-0-004490', 'prediction_text': '약물'},
#  {'id': 'mrc-1-000780', 'prediction_text': '강 노인'},
#  {'id': 'mrc-0-000037', 'prediction_text': '미켈란젤로'},
#  {'id': 'mrc-0-003187', 'prediction_text': '기암절벽'},
#  {'id': 'mrc-1-000021', 'prediction_text': '국가안보상 필요할 경우'},
#  {'id': 'mrc-1-001634', 'prediction_text': '요한 계시록'},
#  {'id': 'mrc-1-000116', 'prediction_text': '베르타카르'},
#  {'id': 'mrc-0-004669', 'prediction_text': '베드로좌'},
#  {'id': 'mrc-0-002210', 'prediction_text': '주기'},
#  {'id': 'mrc-0-004266', 'prediction_text': '영국'},
#  {'id': 'mrc-1-000862', 'prediction_text': '충팽'},
#  {'id': 'mrc-0-001884', 'prediction_text': '전차포와 부무장'},
#  {'id': 'mrc-0-003249', 'prediction_text': '노르웨이'},
#  {'id': 'mrc-0-001728', 'prediction_text': '12,000명'},
#  {'id': 'mrc-0-000986', 'prediction_text': '오스마르'},
#  {'id': 'mrc-0-000970', 'prediction_text': '고천제'},
#  {'id': 'mrc-0-004182', 'prediction_text': '파시즘'},
#  {'id': 'mrc-0-003970', 'prediction_text': '교토 본선과 센리 선'},
#  {'id': 'mrc-0-004626', 'prediction_text': '웅기탁'},
#  {'id': 'mrc-0-000065', 'prediction_text': '1,668만 5천 달러'},
#  {'id': 'mrc-0-003016', 'prediction_text': '신춘문예공모전'},
#  {'id': 'mrc-0-000304', 'prediction_text': '1919년 10월 1일자'},
#  {'id': 'mrc-0-003205', 'prediction_text': '10세기'},
#  {'id': 'mrc-0-002169', 'prediction_text': '다케다 한시'},
#  {'id': 'mrc-0-002771', 'prediction_text': '보이저 탐사선'},
#  {'id': 'mrc-0-003359', 'prediction_text': '모자'},
#  {'id': 'mrc-1-000666', 'prediction_text': '여름철'},
#  {'id': 'mrc-0-003123', 'prediction_text': '세르비아군'},
#  {'id': 'mrc-0-003614', 'prediction_text': '복벽 내'},
#  {'id': 'mrc-1-000791', 'prediction_text': '금융위원회'},
#  {'id': 'mrc-1-001485', 'prediction_text': '에베소'},
#  {'id': 'mrc-1-001025', 'prediction_text': '「티탄즈」'},
#  {'id': 'mrc-0-003425', 'prediction_text': '3차원'},
#  {'id': 'mrc-0-002676', 'prediction_text': '아루에'},
#  {'id': 'mrc-0-001432', 'prediction_text': '기원전 2000년경'},
#  {'id': 'mrc-1-001332', 'prediction_text': '마놀로 비야노바'},
#  {'id': 'mrc-0-001281', 'prediction_text': '사법부'},
#  {'id': 'mrc-0-003224', 'prediction_text': '91 cm 구경의 굴절망원경'},
#  {'id': 'mrc-0-000496',
#   'prediction_text': '5월 7일 저녁 윤창중은 주미 한국대사관에서 파견된 여성 인턴과 워싱턴 숙소 인근 호텔 바에서 술을 마셨다. 인턴 직원이 미국 경찰에 신고한 내용에 따르면, 이날 저녁 9시 30분 윤창중은 인턴 직원의 엉덩이를 움켜쥐었다. 또한 윤창중은 이튿날인 5월 8일'},
#  {'id': 'mrc-0-001384', 'prediction_text': '미술과'},
#  {'id': 'mrc-0-003067', 'prediction_text': '신성 로마 제국'},
#  {'id': 'mrc-0-004545', 'prediction_text': '후군'},
#  {'id': 'mrc-0-004460', 'prediction_text': '영자가 쏜 총'},
#  {'id': 'mrc-0-002975', 'prediction_text': '엘디아'},
#  {'id': 'mrc-0-004389', 'prediction_text': '트루먼의 아빠'},
#  {'id': 'mrc-0-005180', 'prediction_text': 'Lea et al'},
#  {'id': 'mrc-0-001374', 'prediction_text': '1530년'},
#  {'id': 'mrc-0-000431', 'prediction_text': '자기장'},
#  {'id': 'mrc-0-001783', 'prediction_text': '자자 빙크스'},
#  {'id': 'mrc-0-000359', 'prediction_text': '프랑스'},
#  {'id': 'mrc-0-002967', 'prediction_text': 'IS'},
#  {'id': 'mrc-0-001838', 'prediction_text': '1916년'},
#  {'id': 'mrc-0-000021', 'prediction_text': '1862년'},
#  {'id': 'mrc-0-004709', 'prediction_text': '블랙 홀'},
#  {'id': 'mrc-0-003085', 'prediction_text': '80~90%'},
#  {'id': 'mrc-0-005332', 'prediction_text': '백제금동대향로'},
#  {'id': 'mrc-1-001594', 'prediction_text': '자동송환'},
#  {'id': 'mrc-1-000856', 'prediction_text': '목재와 장작을 실어나르고자'},
#  {'id': 'mrc-0-003629', 'prediction_text': '유성생식'},
#  {'id': 'mrc-0-005210', 'prediction_text': '마르크 오버르마르스'},
#  {'id': 'mrc-0-002685', 'prediction_text': '1876년'},
#  {'id': 'mrc-0-002938', 'prediction_text': '찰스 디 페소'},
#  {'id': 'mrc-0-002936', 'prediction_text': '붉은 군대'},
#  {'id': 'mrc-0-002389', 'prediction_text': '유교문화'},
#  {'id': 'mrc-0-003706', 'prediction_text': '천공'},
#  {'id': 'mrc-0-001366', 'prediction_text': '신성 로마 제국'},
#  {'id': 'mrc-0-005387', 'prediction_text': '자동차 폐기장'},
#  {'id': 'mrc-0-003100', 'prediction_text': '히브리 백성'},
#  {'id': 'mrc-0-001021', 'prediction_text': '투사체의 궤적'},
#  {'id': 'mrc-0-000898', 'prediction_text': '이회창'},
#  {'id': 'mrc-1-000256', 'prediction_text': '김장생'},
#  {'id': 'mrc-0-001382', 'prediction_text': '아라리크'},
#  {'id': 'mrc-0-004932', 'prediction_text': '3년'},
#  {'id': 'mrc-1-000008', 'prediction_text': '히틀러의 외투'},
#  {'id': 'mrc-0-002723', 'prediction_text': '"건강 증서"'},
#  {'id': 'mrc-0-005465', 'prediction_text': '쿠파'},
#  {'id': 'mrc-0-003236', 'prediction_text': '프로이센'},
#  {'id': 'mrc-0-003365', 'prediction_text': "'비공식 굿즈'"},
#  {'id': 'mrc-0-002788', 'prediction_text': '합작 5원칙'},
#  {'id': 'mrc-1-000582', 'prediction_text': '소반'},
#  {'id': 'mrc-0-001379', 'prediction_text': '독일'},
#  {'id': 'mrc-0-001445', 'prediction_text': '1915년까지'},
#  {'id': 'mrc-0-000345', 'prediction_text': '주선회'},
#  {'id': 'mrc-0-002584', 'prediction_text': '정규 공간'},
#  {'id': 'mrc-0-004928', 'prediction_text': '하미드 카르자이'},
#  {'id': 'mrc-0-004803', 'prediction_text': '예시 아티드랑 텔렘당'},
#  {'id': 'mrc-0-004927', 'prediction_text': '대체 에너지의 개발'},
#  {'id': 'mrc-1-000536', 'prediction_text': '양극화'},
#  {'id': 'mrc-0-002424', 'prediction_text': '자인단오-한장군 놀이'},
#  {'id': 'mrc-0-000576', 'prediction_text': '나치 정당'},
#  {'id': 'mrc-0-002786', 'prediction_text': '외교부 장관직'},
#  {'id': 'mrc-0-000205', 'prediction_text': 'Chris Avellone'},
#  {'id': 'mrc-0-002518', 'prediction_text': '빙하기 세대'},
#  {'id': 'mrc-0-005293', 'prediction_text': '유니언역'},
#  {'id': 'mrc-1-001027', 'prediction_text': '광주지방검찰청 순천지청'},
#  {'id': 'mrc-0-001105', 'prediction_text': '실존주의 사상'},
#  {'id': 'mrc-0-000122', 'prediction_text': '종신형'},
#  {'id': 'mrc-0-000712', 'prediction_text': '포토맥군'},
#  {'id': 'mrc-0-001896', 'prediction_text': 'P 시리즈'},
#  {'id': 'mrc-0-003227', 'prediction_text': '대구'},
#  {'id': 'mrc-0-002215', 'prediction_text': '따끄옥루앗'},
#  {'id': 'mrc-0-002601', 'prediction_text': '네덜란드의 1, 2도시'},
#  {'id': 'mrc-0-004910', 'prediction_text': '유럽의 서부 전선'},
#  {'id': 'mrc-0-002166', 'prediction_text': '하루'},
#  {'id': 'mrc-0-003503', 'prediction_text': '긴급 구호 건설 법령'},
#  {'id': 'mrc-0-001845', 'prediction_text': '조봉암'},
#  {'id': 'mrc-0-001887', 'prediction_text': '18세기 중후반'},
#  {'id': 'mrc-0-000316', 'prediction_text': '후장식 대포'},
#  {'id': 'mrc-0-003027', 'prediction_text': '리비우스'},
#  {'id': 'mrc-0-005283', 'prediction_text': '감각기에'},
#  {'id': 'mrc-1-001543', 'prediction_text': '머나먼 다리'},
#  {'id': 'mrc-0-002338', 'prediction_text': '루피'},
#  {'id': 'mrc-0-002231', 'prediction_text': '≪악령≫'},
#  {'id': 'mrc-0-002983', 'prediction_text': '초등학교 교원'},
#  {'id': 'mrc-0-004017', 'prediction_text': '정원 초과'},
#  {'id': 'mrc-0-001220', 'prediction_text': '1점'},
#  {'id': 'mrc-0-002746', 'prediction_text': '공룡공원 층'},
#  {'id': 'mrc-0-002285', 'prediction_text': '열적작용'},
#  {'id': 'mrc-0-001844', 'prediction_text': '키릴 문자'},
#  {'id': 'mrc-1-001797', 'prediction_text': '서구 감천동 뒷산'},
#  {'id': 'mrc-0-002028', 'prediction_text': '리을설'},
#  {'id': 'mrc-0-003031', 'prediction_text': '이세민'},
#  {'id': 'mrc-1-001020', 'prediction_text': '팔레스타인'},
#  {'id': 'mrc-0-001574', 'prediction_text': '피오렐로 라과디아와 좌익의 비토 마캔토니오'},
#  {'id': 'mrc-1-000155', 'prediction_text': '1996년 6월 24일'},
#  {'id': 'mrc-1-000801', 'prediction_text': '손가락'},
#  {'id': 'mrc-0-003959', 'prediction_text': '길리포스'},
#  {'id': 'mrc-1-000235', 'prediction_text': "'농지'"},
#  {'id': 'mrc-0-002716', 'prediction_text': '≪지에코초≫'},
#  {'id': 'mrc-0-000014', 'prediction_text': '유대인'},
#  {'id': 'mrc-0-000246', 'prediction_text': '톰 디마르코'},
#  {'id': 'mrc-0-003961', 'prediction_text': '마에노 료타쿠'},
#  {'id': 'mrc-0-001030', 'prediction_text': '2004년'},
#  {'id': 'mrc-1-001600', 'prediction_text': '플랑베르주'},
#  {'id': 'mrc-1-001721', 'prediction_text': '조카 윤보선'},
#  {'id': 'mrc-1-000727', 'prediction_text': '두 가지'},
#  {'id': 'mrc-0-004738', 'prediction_text': '미국연방헌법 수정조항 제5조'},
#  {'id': 'mrc-1-001584', 'prediction_text': '글래스고 대학교'},
#  {'id': 'mrc-1-000387', 'prediction_text': '특정 국가'},
#  {'id': 'mrc-1-001370', 'prediction_text': '국제전시법'},
#  {'id': 'mrc-1-000621', 'prediction_text': '간석기'},
#  {'id': 'mrc-0-001557', 'prediction_text': '아테네'},
#  {'id': 'mrc-0-000850', 'prediction_text': '문장원'},
#  {'id': 'mrc-0-001149', 'prediction_text': '오키나와어'},
#  {'id': 'mrc-0-000288', 'prediction_text': '주자'},
#  {'id': 'mrc-1-001690', 'prediction_text': '국립중앙박물관'},
#  {'id': 'mrc-1-001603', 'prediction_text': '법관 출신 인사'},
#  {'id': 'mrc-0-004363', 'prediction_text': '파비아'},
#  {'id': 'mrc-0-000177', 'prediction_text': '8명'},
#  {'id': 'mrc-0-002514', 'prediction_text': 'API'},
#  {'id': 'mrc-0-001487', 'prediction_text': '85번'},
#  {'id': 'mrc-0-001961', 'prediction_text': '북동풍'},
#  {'id': 'mrc-0-001938', 'prediction_text': '코네티컷 소년원'},
#  {'id': 'mrc-1-001692', 'prediction_text': '15개'},
#  {'id': 'mrc-0-003356', 'prediction_text': '언더우드박사'},
#  {'id': 'mrc-0-000574', 'prediction_text': '1954년'},
#  {'id': 'mrc-0-004196', 'prediction_text': '중풍'},
#  {'id': 'mrc-1-001541', 'prediction_text': '유대인'},
#  {'id': 'mrc-1-000550', 'prediction_text': '마리아의 다섯 가지 기쁨'},
#  {'id': 'mrc-1-000769', 'prediction_text': '보리스 레주킨이 이끄는 분견대'},
#  {'id': 'mrc-0-003442', 'prediction_text': '매개념'},
#  {'id': 'mrc-0-000114', 'prediction_text': '코드'},
#  {'id': 'mrc-0-002868', 'prediction_text': '1875년'},
#  {'id': 'mrc-0-002997', 'prediction_text': '1922년'},
#  {'id': 'mrc-0-002848', 'prediction_text': '잭'},
#  {'id': 'mrc-1-000889', 'prediction_text': '금산전투'},
#  {'id': 'mrc-1-000267', 'prediction_text': '3층'},
#  {'id': 'mrc-0-002654', 'prediction_text': '사운드클라우드 계정'},
#  {'id': 'mrc-0-001363', 'prediction_text': '찰스 2세'},
#  {'id': 'mrc-0-002282', 'prediction_text': '마리 알렌'},
#  {'id': 'mrc-1-001592', 'prediction_text': '매일 저녁'},
#  {'id': 'mrc-1-000013', 'prediction_text': '요새'},
#  {'id': 'mrc-0-003170', 'prediction_text': '1994년'},
#  {'id': 'mrc-0-002758', 'prediction_text': '스페인'},
#  {'id': 'mrc-1-001310', 'prediction_text': '안티트롬빈'},
#  {'id': 'mrc-1-001545', 'prediction_text': '차가운 점액'},
#  {'id': 'mrc-1-001727', 'prediction_text': '수영공원'},
#  {'id': 'mrc-0-004755', 'prediction_text': '에베라이 지역'},
#  {'id': 'mrc-1-001035', 'prediction_text': '절'},
#  {'id': 'mrc-0-000687', 'prediction_text': '5건'},
#  {'id': 'mrc-0-003514', 'prediction_text': '프로이센 왕국군'},
#  {'id': 'mrc-0-004484', 'prediction_text': '전라남도 지역'},
#  {'id': 'mrc-0-004310', 'prediction_text': '일본 가도카와 쇼텐'},
#  {'id': 'mrc-0-002525', 'prediction_text': '<<종횡무진 한국경제>>'},
#  {'id': 'mrc-0-004855', 'prediction_text': '1961년'},
#  {'id': 'mrc-0-001847', 'prediction_text': '콘스탄티노스'},
#  {'id': 'mrc-0-003215', 'prediction_text': '1773년'},
#  {'id': 'mrc-0-000328', 'prediction_text': '사실주의'},
#  {'id': 'mrc-0-002947', 'prediction_text': '신고전주의 양식'},
#  {'id': 'mrc-0-001757', 'prediction_text': '《십만개위십마》'},
#  {'id': 'mrc-0-001778', 'prediction_text': '456년'},
#  {'id': 'mrc-0-002720', 'prediction_text': '하후상'},
#  {'id': 'mrc-0-003413', 'prediction_text': '스톤페리어'},
#  {'id': 'mrc-0-004594',
#   'prediction_text': '중장기적 인구감소와 그에 따른 잠재적 성장률 저하와 중소기업의 심각한 노동력부족, 심각한 연수제도의 문제점을 해결하기에 위하'},
#  {'id': 'mrc-0-001133', 'prediction_text': '언카스'},
#  {'id': 'mrc-1-000320', 'prediction_text': '1번 ~ 9번'},
#  {'id': 'mrc-0-003669', 'prediction_text': '법무성이'},
#  {'id': 'mrc-1-001443', 'prediction_text': '일리노이주'},
#  {'id': 'mrc-0-004862', 'prediction_text': '정통 칼리프 시대'},
#  {'id': 'mrc-1-001549', 'prediction_text': '경추'},
#  {'id': 'mrc-0-003821', 'prediction_text': '카르도나의 군대'},
#  {'id': 'mrc-0-002832', 'prediction_text': '경험이나 기량'},
#  {'id': 'mrc-1-000691', 'prediction_text': '말'},
#  {'id': 'mrc-0-001607', 'prediction_text': '스렝이'},
#  {'id': 'mrc-0-003454', 'prediction_text': '1997년)'},
#  {'id': 'mrc-0-000206', 'prediction_text': '2월 혁명'},
#  {'id': 'mrc-0-001179', 'prediction_text': '소프트웨어 엔지니어링'},
#  {'id': 'mrc-0-003043', 'prediction_text': '다카사키 기관고'},
#  {'id': 'mrc-0-004648', 'prediction_text': '식후 졸림증'},
#  {'id': 'mrc-0-003434', 'prediction_text': '재산권 박탈'},
#  {'id': 'mrc-0-002074', 'prediction_text': '3턴'},
#  {'id': 'mrc-1-000580', 'prediction_text': '에렌 예거와 아르민'},
#  {'id': 'mrc-0-005097', 'prediction_text': '갈리아인'},
#  {'id': 'mrc-0-001324', 'prediction_text': '강원도'},
#  {'id': 'mrc-0-002816', 'prediction_text': '"문학 혁명"'},
#  {'id': 'mrc-0-000895', 'prediction_text': '파충류'},
#  {'id': 'mrc-0-002127', 'prediction_text': '4막 3장이'},
#  {'id': 'mrc-0-002436', 'prediction_text': '오스트리아-헝가리 제국 시대'},
#  {'id': 'mrc-0-002265', 'prediction_text': '1935년'},
#  {'id': 'mrc-0-003068', 'prediction_text': '시구르드'},
#  {'id': 'mrc-0-001438', 'prediction_text': '옥잠장로'},
#  {'id': 'mrc-0-001072', 'prediction_text': '새정치민주연합'},
#  {'id': 'mrc-0-002927', 'prediction_text': '12척'},
#  {'id': 'mrc-0-000028', 'prediction_text': '김 대령'},
#  {'id': 'mrc-1-000292', 'prediction_text': '오티스 소프'},
#  {'id': 'mrc-0-001415', 'prediction_text': '제1대 총무주석간사'},
#  {'id': 'mrc-0-000499', 'prediction_text': '극단적인 자전축 경사'},
#  {'id': 'mrc-1-000650', 'prediction_text': '광물'},
#  {'id': 'mrc-0-000780', 'prediction_text': '밖'},
#  {'id': 'mrc-1-001635', 'prediction_text': '배우자'},
#  {'id': 'mrc-0-003105', 'prediction_text': '폭동'},
#  {'id': 'mrc-0-001689', 'prediction_text': '1671년'},
#  {'id': 'mrc-0-002170', 'prediction_text': '《소우기》'},
#  {'id': 'mrc-0-000964', 'prediction_text': '하리수'},
#  {'id': 'mrc-0-002414', 'prediction_text': '왼발'},
#  {'id': 'mrc-0-000668', 'prediction_text': '대릉원'},
#  {'id': 'mrc-0-003544', 'prediction_text': '프랑스'},
#  {'id': 'mrc-0-002033', 'prediction_text': '정치평론면'},
#  {'id': 'mrc-1-000189', 'prediction_text': '공수부대'},
#  {'id': 'mrc-0-003180', 'prediction_text': '한스 칼 폰 빈터펠트 장군'},
#  {'id': 'mrc-1-001214', 'prediction_text': 'CP0의 요원'},
#  {'id': 'mrc-0-004245', 'prediction_text': '외무대신'},
#  {'id': 'mrc-1-001689', 'prediction_text': '카네츠 신베에'},
#  {'id': 'mrc-0-002777', 'prediction_text': '삼흥'},
#  {'id': 'mrc-1-001394', 'prediction_text': '"바라아"'},
#  {'id': 'mrc-1-001716', 'prediction_text': '1945년'},
#  {'id': 'mrc-0-002979', 'prediction_text': '5칸'},
#  {'id': 'mrc-0-002493', 'prediction_text': '미국'},
#  {'id': 'mrc-0-002092', 'prediction_text': '「소방공무원법」'},
#  {'id': 'mrc-0-002536', 'prediction_text': '다니엘 슈타이벨트'},
#  {'id': 'mrc-0-002219', 'prediction_text': '위험한 물질'},
#  {'id': 'mrc-1-001196', 'prediction_text': '김진규'},
#  {'id': 'mrc-0-004690', 'prediction_text': '리 컬른'},
#  {'id': 'mrc-0-002045', 'prediction_text': '이만'},
#  {'id': 'mrc-0-002879', 'prediction_text': '이스라엘'},
#  {'id': 'mrc-0-003617', 'prediction_text': '레온 트로츠키'},
#  {'id': 'mrc-0-002618', 'prediction_text': '오가와 오사무'},
#  {'id': 'mrc-0-001614', 'prediction_text': '조선 후기'},
#  {'id': 'mrc-0-004674', 'prediction_text': '테코아쿠'},
#  {'id': 'mrc-0-000393', 'prediction_text': '7월초'},
#  {'id': 'mrc-0-003645', 'prediction_text': '<밤으로의 긴 여행>'},
#  {'id': 'mrc-0-001272', 'prediction_text': '포항교도소'},
#  {'id': 'mrc-0-000740', 'prediction_text': '학습자가 정보 통달에 이를 때까지'},
#  {'id': 'mrc-0-003639', 'prediction_text': '말뿌리'},
#  {'id': 'mrc-0-003904', 'prediction_text': '1922년'},
#  {'id': 'mrc-0-005094', 'prediction_text': '여성 금주 동맹'},
#  {'id': 'mrc-0-005209', 'prediction_text': '홍등가'},
#  {'id': 'mrc-0-003716', 'prediction_text': '오스트리아'},
#  {'id': 'mrc-0-004081', 'prediction_text': '세계 최대의 해류'},
#  {'id': 'mrc-0-001180', 'prediction_text': '1811년'},
#  {'id': 'mrc-0-001046', 'prediction_text': '프랭클린 D. 루스벨트'},
#  {'id': 'mrc-0-001863', 'prediction_text': '베다의 권위를 인정하는 가의 여부'},
#  {'id': 'mrc-0-003926', 'prediction_text': '서재필'},
#  {'id': 'mrc-0-000500', 'prediction_text': '2008년'},
#  {'id': 'mrc-0-001654', 'prediction_text': '붉은 구슬'},
#  {'id': 'mrc-0-001123', 'prediction_text': '레반스라움'},
#  {'id': 'mrc-1-000056', 'prediction_text': '패트릭 자라'},
#  {'id': 'mrc-0-000852', 'prediction_text': '가족의 화합'},
#  {'id': 'mrc-0-003331', 'prediction_text': '200만 달러'},
#  {'id': 'mrc-1-001071', 'prediction_text': '남자아이 빈'},
#  {'id': 'mrc-0-001192', 'prediction_text': '박근혜 대통령'},
#  {'id': 'mrc-0-005108', 'prediction_text': '나이팅게일'},
#  {'id': 'mrc-0-004329', 'prediction_text': '황소'},
#  {'id': 'mrc-1-001425', 'prediction_text': '260억 개'},
#  {'id': 'mrc-1-001769', 'prediction_text': '헝가리'},
#  {'id': 'mrc-0-002916', 'prediction_text': '퀸투스 루타티우스 카툴루스'},
#  {'id': 'mrc-0-000435', 'prediction_text': '젊은이들'},
#  {'id': 'mrc-1-001269', 'prediction_text': '패닌'},
#  {'id': 'mrc-0-000459', 'prediction_text': '내각회의'},
#  {'id': 'mrc-1-000713', 'prediction_text': '드주드주아나의 동굴'},
#  {'id': 'mrc-1-000218', 'prediction_text': '《나뭇잎의 집》'},
#  {'id': 'mrc-0-004970', 'prediction_text': '한 번'},
#  {'id': 'mrc-1-000690', 'prediction_text': '츠와몬'},
#  {'id': 'mrc-0-003499', 'prediction_text': '초음파 가습기'},
#  {'id': 'mrc-1-000181', 'prediction_text': '강세황'},
#  {'id': 'mrc-0-003996', 'prediction_text': '토우야'},
#  {'id': 'mrc-0-004708', 'prediction_text': '땅 속이나 나무 줄기 사이'},
#  {'id': 'mrc-0-005410', 'prediction_text': '오미이마즈 역에서 병결 및 분리를 하는 동안'},
#  {'id': 'mrc-0-004579', 'prediction_text': '아이즈 번'},
#  {'id': 'mrc-0-001793', 'prediction_text': '플라티니'},
#  {'id': 'mrc-0-000255', 'prediction_text': '인사관리에 대한 통제권'},
#  {'id': 'mrc-0-001705', 'prediction_text': '슈베르트'},
#  {'id': 'mrc-0-001539', 'prediction_text': '목포'},
#  {'id': 'mrc-1-001624', 'prediction_text': '가즈사 국'},
#  {'id': 'mrc-1-000694', 'prediction_text': '연청권'},
#  {'id': 'mrc-0-001425', 'prediction_text': '중심지 이동설'},
#  {'id': 'mrc-1-001516', 'prediction_text': '가속화 분류기'},
#  {'id': 'mrc-1-000954', 'prediction_text': '1989년'},
#  {'id': 'mrc-0-005166', 'prediction_text': '괜찮다고'},
#  {'id': 'mrc-0-000096', 'prediction_text': '2009년 8월'},
#  {'id': 'mrc-0-003596', 'prediction_text': '부당한 일요등교 지시'},
#  {'id': 'mrc-0-002651', 'prediction_text': '영국'},
#  {'id': 'mrc-0-001370', 'prediction_text': '특수목적회사 M2G'},
#  {'id': 'mrc-0-002766', 'prediction_text': '1969년'},
#  {'id': 'mrc-0-000150', 'prediction_text': '0-1'},
#  {'id': 'mrc-0-000760', 'prediction_text': '공개 프록시'},
#  {'id': 'mrc-1-000870', 'prediction_text': '마하프라즈냐파라미타샤스트라'},
#  {'id': 'mrc-1-001011', 'prediction_text': '뷔르츠부르크 대학교'},
#  {'id': 'mrc-1-000112', 'prediction_text': '순치제'},
#  {'id': 'mrc-0-004510', 'prediction_text': '인체의 치수'},
#  {'id': 'mrc-1-001436', 'prediction_text': '앙리 블랑슈'},
#  {'id': 'mrc-0-002482', 'prediction_text': '근원 마그마가 형성되는 기작이 다르기 때문'},
#  {'id': 'mrc-0-000527', 'prediction_text': '정려문'},
#  {'id': 'mrc-0-004840', 'prediction_text': '초나라'},
#  {'id': 'mrc-0-001931', 'prediction_text': '독일 제6군'},
#  {'id': 'mrc-0-004832', 'prediction_text': '공병우 자판'},
#  {'id': 'mrc-1-001729', 'prediction_text': '수리물리학'},
#  {'id': 'mrc-0-000866', 'prediction_text': '1945년'},
#  {'id': 'mrc-1-000278', 'prediction_text': '구술'},
#  {'id': 'mrc-0-000723', 'prediction_text': '빛'},
#  {'id': 'mrc-0-000942', 'prediction_text': '모터크로스 레이서'},
#  {'id': 'mrc-0-004280', 'prediction_text': '사츠키'},
#  {'id': 'mrc-1-000518', 'prediction_text': '아드레날린'},
#  {'id': 'mrc-0-004371', 'prediction_text': '윈스턴 처칠'},
#  {'id': 'mrc-1-001582', 'prediction_text': '1934년'},
#  {'id': 'mrc-0-002164', 'prediction_text': '《완전한 죽음》'},
#  {'id': 'mrc-0-001076', 'prediction_text': '베다는'},
#  {'id': 'mrc-0-003962', 'prediction_text': '뉴질랜드'},
#  {'id': 'mrc-1-000094', 'prediction_text': '구와바라'},
#  {'id': 'mrc-1-001301', 'prediction_text': '캘빈 쿨리지'},
#  {'id': 'mrc-0-002763', 'prediction_text': '남궁후'},
#  {'id': 'mrc-0-001429', 'prediction_text': '제노바 공화국'},
#  {'id': 'mrc-1-000651', 'prediction_text': '서울시 종로구 종로4가 동원예식장 뒤뜰'},
#  {'id': 'mrc-0-004649', 'prediction_text': '내각'},
#  {'id': 'mrc-0-004438',
#   'prediction_text': '과학적인 의문에 대한 답변을 얻거나 문제에 대한 조사를 하기 위한 목적'},
#  {'id': 'mrc-0-005422', 'prediction_text': '옥시전 디스트로이어'},
#  {'id': 'mrc-0-000845', 'prediction_text': '오삼계'},
#  {'id': 'mrc-0-002188', 'prediction_text': '104번 위치의 글루탐산'},
#  {'id': 'mrc-0-003648', 'prediction_text': '상대적 손실 가치'},
#  {'id': 'mrc-0-003069', 'prediction_text': '블루 라인'},
#  {'id': 'mrc-0-004759', 'prediction_text': '하이브리드 잉크 배합물'},
#  {'id': 'mrc-1-000412', 'prediction_text': '미하일린'},
#  {'id': 'mrc-0-001078', 'prediction_text': '1946년'},
#  {'id': 'mrc-0-000394', 'prediction_text': '조명록'},
#  {'id': 'mrc-0-002289',
#   'prediction_text': '가덕수로를 따라 올라가야 하는 곳이며 그 곳에 일본군들은 눌차왜성을 축성하였다. 즉 반드시 조선수군이 지나가야 하는 길목에 눌차왜성을 축성하였으며 눌차왜성에서 보면 가덕수로를 따라서 지나가는 조선수군의 모습을 알 수 있다. 일본군들도 조선군이 반드시 지나가야 하는 곳'},
#  {'id': 'mrc-0-000734', 'prediction_text': '언더우드 박사'},
#  {'id': 'mrc-1-000770', 'prediction_text': '중동 건설 현장'},
#  {'id': 'mrc-0-004187', 'prediction_text': '승려'},
#  {'id': 'mrc-1-001554', 'prediction_text': '야기옐론 대학'},
#  {'id': 'mrc-0-000062', 'prediction_text': '전달판'},
#  {'id': 'mrc-0-003460', 'prediction_text': '레기온'},
#  {'id': 'mrc-0-003038', 'prediction_text': '요한'},
#  {'id': 'mrc-0-001682', 'prediction_text': '구금'},
#  {'id': 'mrc-0-001457', 'prediction_text': '일본'},
#  {'id': 'mrc-1-000143', 'prediction_text': '밀양 농잠학교'},
#  {'id': 'mrc-0-003755', 'prediction_text': '무신'},
#  {'id': 'mrc-0-001393', 'prediction_text': '마이클 뉴먼'},
#  {'id': 'mrc-0-001790', 'prediction_text': '스카버러 타운 센터'},
#  {'id': 'mrc-0-003418', 'prediction_text': '의사결정권자'},
#  {'id': 'mrc-0-002696', 'prediction_text': '1948년'},
#  {'id': 'mrc-0-004465', 'prediction_text': '와히드 박사'},
#  {'id': 'mrc-0-002840', 'prediction_text': '화이트워터 사건'},
#  {'id': 'mrc-1-000972', 'prediction_text': '솔라 레이'},
#  {'id': 'mrc-1-000227', 'prediction_text': '러시아 기병대'},
#  {'id': 'mrc-0-002155', 'prediction_text': '서울'},
#  {'id': 'mrc-0-000564', 'prediction_text': '1970년'},
#  {'id': 'mrc-0-001660', 'prediction_text': '6미터'},
#  {'id': 'mrc-0-004323', 'prediction_text': '강력범죄 특별수사관'},
#  {'id': 'mrc-0-000664', 'prediction_text': '벤자민 바커'},
#  {'id': 'mrc-0-000913', 'prediction_text': '탈당'},
#  {'id': 'mrc-0-004373', 'prediction_text': '5월 29일'},
#  {'id': 'mrc-0-004392', 'prediction_text': '뇌'},
#  {'id': 'mrc-1-001229', 'prediction_text': '교황 요한 바오로 2세이'},
#  {'id': 'mrc-0-005342', 'prediction_text': '소루트비히'},
#  {'id': 'mrc-0-000030', 'prediction_text': '목재 오두막집'},
#  {'id': 'mrc-0-002098', 'prediction_text': '교황 율리오 2세'},
#  {'id': 'mrc-0-000162', 'prediction_text': '1. FFC 투르비네 포츠담'},
#  {'id': 'mrc-0-000784', 'prediction_text': '프랑스'},
#  {'id': 'mrc-0-004040', 'prediction_text': '안티오쿠스'},
#  {'id': 'mrc-1-001277', 'prediction_text': '좀비'},
#  {'id': 'mrc-0-000434', 'prediction_text': '인질이 된 다케치요(이에야스)의 양육을 위해'},
#  {'id': 'mrc-0-002096', 'prediction_text': '1947년'},
#  {'id': 'mrc-0-001878', 'prediction_text': '입석대'},
#  {'id': 'mrc-0-000211', 'prediction_text': '실루엣'},
#  {'id': 'mrc-0-004085', 'prediction_text': '조쉬 맥킨지'},
#  {'id': 'mrc-0-004909', 'prediction_text': '모술'},
#  {'id': 'mrc-0-003441',
#   'prediction_text': "렌나르트는 연설 '에스토니아는 희망을 가졌는가'를 통해 국가 존립 문제에 초점을 맞추고 대외적으로 대단한 파급효과를 내었다. 1988년에는 에스토니아 인민전선의 창립위원으로서 라트비아"},
#  {'id': 'mrc-0-003807', 'prediction_text': '키홀더'},
#  {'id': 'mrc-0-001026', 'prediction_text': '86'},
#  {'id': 'mrc-1-000524', 'prediction_text': '슬로보단 밀로셰비치'},
#  {'id': 'mrc-0-001864', 'prediction_text': '보리스 타디치'},
#  {'id': 'mrc-0-004467', 'prediction_text': '1994년'},
#  {'id': 'mrc-0-002636', 'prediction_text': '1977년'},
#  {'id': 'mrc-0-004710', 'prediction_text': '공훈의 보상'},
#  {'id': 'mrc-0-002581', 'prediction_text': '중앙위원회'},
#  {'id': 'mrc-0-005012', 'prediction_text': '"이탈리아 요리"'},
#  {'id': 'mrc-0-003040', 'prediction_text': '일본'},
#  {'id': 'mrc-0-003558', 'prediction_text': '연방 정부'},
#  {'id': 'mrc-1-001670', 'prediction_text': '현무암 화방벽'},
#  {'id': 'mrc-0-004531', 'prediction_text': '판옥선'},
#  {'id': 'mrc-0-003835', 'prediction_text': '토스카나'},
#  {'id': 'mrc-0-002683', 'prediction_text': '1722년'},
#  {'id': 'mrc-0-003770', 'prediction_text': '"명련사"'},
#  {'id': 'mrc-0-003053', 'prediction_text': '조선혁명간부학교'},
#  {'id': 'mrc-1-001426', 'prediction_text': '한일합의'},
#  {'id': 'mrc-0-002782', 'prediction_text': '선조'},
#  {'id': 'mrc-0-002245', 'prediction_text': '레드훅 스튜디오'},
#  {'id': 'mrc-0-004111', 'prediction_text': '1924년'},
#  {'id': 'mrc-1-001775', 'prediction_text': '카르멜 수녀원'},
#  {'id': 'mrc-0-002130', 'prediction_text': '러시아 제국'},
#  {'id': 'mrc-1-001559', 'prediction_text': '소방방재센터'},
#  {'id': 'mrc-1-000627', 'prediction_text': '1967년 11월 15일'},
#  {'id': 'mrc-0-004672', 'prediction_text': '클링조르'},
#  {'id': 'mrc-1-001051', 'prediction_text': '나르샤(날아 오르다) 선발대회'},
#  {'id': 'mrc-1-001316', 'prediction_text': '창립기'},
#  {'id': 'mrc-1-000977', 'prediction_text': "'나는 참된 보통 선거를 원한다'"},
#  {'id': 'mrc-1-000788', 'prediction_text': '뉴욕'},
#  {'id': 'mrc-0-002530', 'prediction_text': '안티오코스 3세'},
#  {'id': 'mrc-0-002481', 'prediction_text': '세 가지'},
#  {'id': 'mrc-0-000283', 'prediction_text': '비올라'},
#  {'id': 'mrc-0-003501', 'prediction_text': '백병계열군'},
#  {'id': 'mrc-0-003500', 'prediction_text': '급소'},
#  {'id': 'mrc-0-004308', 'prediction_text': '356'},
#  {'id': 'mrc-1-000841', 'prediction_text': '한진창'},
#  {'id': 'mrc-1-001669', 'prediction_text': '법당 앞 마당'},
#  {'id': 'mrc-0-005486', 'prediction_text': '조조'},
#  {'id': 'mrc-0-004372', 'prediction_text': '대구'},
#  {'id': 'mrc-0-000944', 'prediction_text': '물'},
#  {'id': 'mrc-0-004410', 'prediction_text': '시릴 라마포사 대통령'},
#  {'id': 'mrc-0-001659', 'prediction_text': '펠리페 왕은 아들과 왕비 엘리자베트 사이를 의심'},
#  {'id': 'mrc-0-002991', 'prediction_text': '아유미'},
#  {'id': 'mrc-0-001251', 'prediction_text': '공화당원 투표인들 만을 화나게 할 것'},
#  {'id': 'mrc-0-003528', 'prediction_text': '어사대부'},
#  {'id': 'mrc-0-002877', 'prediction_text': '빌트루디스'},
#  {'id': 'mrc-1-000177', 'prediction_text': '제8조'},
#  {'id': 'mrc-0-005447', 'prediction_text': '석재'},
#  {'id': 'mrc-1-001517', 'prediction_text': '강원도관찰사'},
#  {'id': 'mrc-0-003711', 'prediction_text': '성철'},
#  {'id': 'mrc-0-004394', 'prediction_text': '프리드리히 니체'},
#  {'id': 'mrc-0-004335', 'prediction_text': '뉴욕타임스'},
#  {'id': 'mrc-0-000651', 'prediction_text': '1967년'},
#  {'id': 'mrc-0-002989', 'prediction_text': '재단 X'},
#  {'id': 'mrc-0-001804', 'prediction_text': '자유당계 인사들'},
#  {'id': 'mrc-0-003411', 'prediction_text': '서스펜디드 게임'},
#  {'id': 'mrc-0-003436', 'prediction_text': '샹포'},
#  {'id': 'mrc-0-002605', 'prediction_text': '수수께끼의 콘드률'}]
